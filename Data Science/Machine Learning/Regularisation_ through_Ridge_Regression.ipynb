# %%
import numpy as np
import pandas as pd
import random

# %%
outcome = []
for i in range(1000000):
    outcome.append(random.randint(1,6))
    
np.array(outcome).mean()
# Out:
# 3.500934

# %%
from mlxtend.evaluate import bias_variance_decomp
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from mlxtend.data import boston_housing_data
from sklearn.model_selection import train_test_split

# %%
X,y = boston_housing_data()

# %%
print(X)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(y)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 123,shuffle = True)

# %%
print(X_train)
# Out:
# [[2.21880e-01 2.00000e+01 6.96000e+00 ... 1.86000e+01 3.90770e+02
#   6.58000e+00]
#  [5.36000e-02 2.10000e+01 5.64000e+00 ... 1.68000e+01 3.96900e+02
#   5.28000e+00]
#  [6.88800e-02 0.00000e+00 2.46000e+00 ... 1.78000e+01 3.96900e+02
#   9.45000e+00]
#  ...
#  [3.51140e-01 0.00000e+00 7.38000e+00 ... 1.96000e+01 3.96900e+02
#   7.70000e+00]
#  [9.18702e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.96900e+02
#   2.36000e+01]
#  [4.55587e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.54700e+02
#   7.12000e+00]]

# %%
print(y_train)
# Out:
# [35.2 25.  36.2 16.1 10.9 36.4 25.  20.1 16.8 23.7 42.3 17.9 12.7 50.
#  18.4 33.4 22.9 14.6 29.9 22.6 22.5 29.  50.  37.9 21.4 29.4 20.3 23.
#  30.1 21.7 36.5 25.  24.5 37.3 33.8 24.7 32.7 23.1 25.1 21.7 13.4 24.8
#  12.7 11.8  8.3 20.2 41.3 23.2 23.1 24.3 19.3 10.8 18.6 29.  23.9 19.5
#  13.1 31.7 21.  18.2 21.  21.2 14.1 33.2 13.8 19.9 21.7 20.6 21.2 13.6
#  18.9 18.  24.1 28.7 23.4 15.2 23.6 13.8 11.7 16.3 50.  13.5 50.  31.5
#  22.6 12.1 21.7 14.1 22.4 13.4 33.1 20.6  8.3 36.2  6.3 21.5 23.3 24.
#  19.1 29.6 27.9 16.2  9.5 24.6 15.6  8.1 15.3 19.  22.  28.  19.2 14.5
#   9.7 30.7 20.6 16.  19.8 17.8 21.2 28.7 41.7  7.2 13.4 17.7 26.7 23.8
#  21.8 27.1 18.3  5.  10.4 18.5 17.4 28.6 50.  14.2 31.2  8.4 23.  35.1
#  23.9 20.3 46.7 15.  18.4 17.8 22.5 18.8 20.9 50.  29.1 17.1 10.5 18.8
#  27.5 19.5 22.   5.  21.7 50.  35.4 32.  20.5 16.8 22.9  8.5 50.  22.2
#  15.2 22.6  7.  19.3 26.4 12.8 19.2 19.7 38.7 30.3 25.  23.7 11.7 17.5
# ...

# %%
lr = LinearRegression()

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(lr, X_train, y_train, X_test, y_test, loss='mse',random_seed=123)
print('avg_expected_loss:- ',avg_expected_loss)
print('avg_bias:-', avg_bias)
print('avg_variance:- ',avg_var)
# Out:
# avg_expected_loss:-  29.891450216347586
# avg_bias:- 28.609233801954336
# avg_variance:-  1.2822164143932513

# %%
dt = DecisionTreeRegressor()

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(dt, X_train, y_train, X_test, y_test, loss='mse',random_seed=123)
print('avg_expected_loss:- ',avg_expected_loss)
print('avg_bias:-', avg_bias)
print('avg_variance:- ',avg_var)
# Out:
# avg_expected_loss:-  33.41952960526316
# avg_bias:- 14.5704674506579
# avg_variance:-  18.84906215460526

# %% [markdown]
# # RIDGE REGRESSION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()
data
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X = data.data
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y = data.target
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %%
X_train
# Out:
# array([[-0.00188202, -0.04464164, -0.06979687, ..., -0.03949338,
#         -0.06291688,  0.04034337],
#        [-0.00914709, -0.04464164,  0.01103904, ..., -0.03949338,
#          0.01703607, -0.0052198 ],
#        [ 0.02354575,  0.05068012, -0.02021751, ..., -0.03949338,
#         -0.09643495, -0.01764613],
#        ...,
#        [ 0.06350368,  0.05068012, -0.00405033, ..., -0.00259226,
#          0.08449153, -0.01764613],
#        [-0.05273755,  0.05068012, -0.01806189, ...,  0.1081111 ,
#          0.03606033, -0.04249877],
#        [ 0.00175052,  0.05068012,  0.05954058, ...,  0.1081111 ,
#          0.06898589,  0.12732762]])

# %%
y_train
# Out:
# array([ 48., 276.,  47., 175.,  60.,  81., 242., 197., 137., 129., 138.,
#        160., 116., 101., 147., 100., 144.,  69., 219., 107., 168., 236.,
#        109., 321., 128.,  43.,  72.,  55., 141., 283.,  59., 150., 346.,
#        124., 186., 308., 272., 190.,  63.,  91.,  72.,  65., 158.,  90.,
#        185.,  45., 199., 206.,  61., 139., 296., 281., 122.,  95.,  40.,
#        127., 145., 108., 185.,  53., 132., 101., 263.,  94., 295., 259.,
#        232., 124.,  77., 102.,  96.,  83., 263.,  71., 246.,  66., 115.,
#        222.,  93., 129., 128., 163.,  99.,  92., 179., 140.,  94.,  97.,
#        174.,  61., 202., 135.,  88., 152.,  69.,  31., 248., 275.,  64.,
#         94.,  99., 109.,  90.,  37., 164., 274., 200.,  49., 214.,  85.,
#        154., 134., 164., 189.,  64., 150., 245.,  67., 265., 151.,  75.,
#        208., 292.,  90.,  59.,  44., 277.,  67.,  72., 182., 135., 275.,
#         95., 332., 214.,  53., 141., 102.,  88.,  74., 103., 292.,  70.,
# ...

# %%
from sklearn.linear_model import LinearRegression
L= LinearRegression()

# %%
L.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(L.coef_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]

# %%
print(L.intercept_)
# Out:
# 151.88331005254167

# %%
y_pred = L.predict(X_test)
y_pred
# Out:
# array([154.1213881 , 204.81835118, 124.93755353, 106.08950893,
#        258.5348576 , 256.3310074 , 118.75087616, 119.52440696,
#        101.50816735, 190.54048661, 141.70656811, 172.51883961,
#        174.33861649, 134.80942706, 294.13994537,  94.11798038,
#        211.97059795, 156.49579378, 134.21000428, 119.62664644,
#        148.87842251, 165.00873409, 151.10021038, 176.04063756,
#        133.27769647, 221.29555392, 197.17324941,  96.1577688 ,
#         50.26012711, 230.48580317, 242.06073866, 114.11129218,
#         67.07532417,  94.52943825, 201.21415375, 167.05136201,
#        159.881268  , 192.78746659, 114.49551325, 233.48234551,
#        140.82563045, 121.0680409 , 192.27480772, 191.12738845,
#        179.16865788, 148.34935601, 163.47414622, 276.81647884,
#        100.17926432, 164.10555298, 255.80762189, 136.9466204 ,
#        152.37503699, 107.92237882, 194.21924678,  77.34670792,
#        118.50482479,  68.38335763, 154.29258529, 162.48840259,
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error
print('r2_score:- ',r2_score(y_test,y_pred))
print('rmse:- ',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score:-  0.4399338661568968
# rmse:-  55.627840795469155

# %%
from sklearn.metrics import r2_score,mean_squared_error

print("R2 score",r2_score(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.4399338661568968
# RMSE 55.627840795469155

# %%
from sklearn.linear_model import Ridge
R=Ridge(alpha=100000)

# %%
R.fit(X_train,y_train)
# Out:
# Ridge(alpha=100000)

# %%
print(R.coef_)
print(R.intercept_)
# Out:
# [ 0.00296842  0.00070013  0.00770694  0.00599277  0.00284245  0.00227272
#  -0.0049699   0.00528873  0.00763383  0.00472551]
# 150.4589824154056

# %%
y_pred1=R.predict(X_test)
y_pred
# Out:
# array([154.1213881 , 204.81835118, 124.93755353, 106.08950893,
#        258.5348576 , 256.3310074 , 118.75087616, 119.52440696,
#        101.50816735, 190.54048661, 141.70656811, 172.51883961,
#        174.33861649, 134.80942706, 294.13994537,  94.11798038,
#        211.97059795, 156.49579378, 134.21000428, 119.62664644,
#        148.87842251, 165.00873409, 151.10021038, 176.04063756,
#        133.27769647, 221.29555392, 197.17324941,  96.1577688 ,
#         50.26012711, 230.48580317, 242.06073866, 114.11129218,
#         67.07532417,  94.52943825, 201.21415375, 167.05136201,
#        159.881268  , 192.78746659, 114.49551325, 233.48234551,
#        140.82563045, 121.0680409 , 192.27480772, 191.12738845,
#        179.16865788, 148.34935601, 163.47414622, 276.81647884,
#        100.17926432, 164.10555298, 255.80762189, 136.9466204 ,
#        152.37503699, 107.92237882, 194.21924678,  77.34670792,
#        118.50482479,  68.38335763, 154.29258529, 162.48840259,
# ...

# %%
print("R2 score",r2_score(y_test,y_pred1))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score -0.012493689570653332
# RMSE 74.79433571886918

# %%
# Generating the data

m = 100
x1 = 5* np.random.rand(m,1) -2
x2 = 0.7 * x1 ** 2 - 2 * x1 + 3 + np.random.randn(m, 1)

plt.scatter(x1,x2)
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %%
def get_preds_ridge(x1, x2, alpha):
    model = Pipeline([
        ('poly_feats', PolynomialFeatures(degree=16)),
        ('ridge', Ridge(alpha=alpha))
    ])
    model.fit(x1, x2)
    return model.predict(x1)

alphas = [0, 20, 200]
cs = ['r', 'g', 'b']

plt.figure(figsize=(10, 6))
plt.plot(x1, x2, 'b+', label='Datapoints')

for alpha, c in zip(alphas, cs):
    preds = get_preds_ridge(x1, x2, alpha)
    # Plot
    plt.plot(sorted(x1[:, 0]), preds[np.argsort(x1[:, 0])], c, label='Alpha: {}'.format(alpha))

plt.legend()
plt.show()

# %% [markdown]
# # ridge-regression-from-scratch

# %%
from sklearn.datasets import make_regression
data = make_regression()
data
# Out:
# (array([[ 0.69132714,  0.64167372, -0.63495529, ...,  0.43243349,
#           2.60778328, -0.31781489],
#         [ 1.06137128,  0.66121735, -0.23386962, ..., -0.65175746,
#          -0.95946507, -1.25085804],
#         [-0.58197051,  0.72183996,  0.48463557, ..., -0.08592852,
#          -0.98341503,  1.90641985],
#         ...,
#         [-0.16447175,  1.98961928,  0.88279215, ...,  0.1646532 ,
#          -1.04860005,  1.56067688],
#         [-0.09179346, -0.16583287,  1.64097459, ..., -0.01394387,
#           0.68051246, -1.32157815],
#         [ 0.24002386,  0.34532791, -1.66097702, ..., -0.60415439,
#           0.95076701,  0.16390761]]),
#  array([-308.33574702,  303.03251363,   13.94854682, -126.65063795,
#         -293.54799126,  -47.28260196, -197.12065156,   11.94054742,
#          173.45034835,   53.86153726,  267.03532434,   45.58452338,
#          131.65923529, -426.14183502, -108.62010122,  230.87002   ,
# ...

# %%
X2,y2 = make_regression(n_samples = 100,n_features = 1,n_informative = 1,n_targets=1,noise=20,random_state=13)
print(X2)
# Out:
# [[-0.71239066]
#  [-0.43714566]
#  [-0.45375238]
#  [ 0.95283061]
#  [ 0.23785784]
#  [ 0.86121137]
#  [-0.24332625]
#  [ 0.18494595]
#  [-0.72099967]
#  [-0.42989708]
#  [ 2.01522083]
#  [ 0.39724133]
#  [ 0.20780005]
#  [-0.23242587]
#  [-0.76862702]
#  [ 0.45315861]
#  [ 0.63988397]
#  [ 0.3595323 ]
#  [-1.61510796]
#  [ 1.74924179]
#  [-0.78898902]
#  [-0.51196509]
#  [-0.92833523]
#  [ 2.15038297]
#  [-0.2073497 ]
#  [-1.63909341]
#  [-0.33861825]
#  [-0.32212366]
#  [-0.48137142]
#  [-0.52316421]
#  [ 0.72196506]
#  [ 0.76591105]
#  [ 0.45348104]
#  [-1.26160595]
#  [-2.18711527]
#  [-1.18541881]
#  [ 0.21745166]
#  [ 1.33031692]
#  [-1.08718159]
#  [ 0.56226171]
#  [-1.51284512]
#  [-0.00238903]
#  [-0.27813452]
#  [ 0.45181234]
#  [ 1.19070527]
#  [ 0.92234415]
#  [ 0.81499544]
#  [-0.6209797 ]
#  [ 0.9137407 ]
#  [ 1.13833305]
#  [ 1.47868574]
#  [-0.65105648]
#  [-0.37591996]
#  [-0.77466003]
#  [ 0.50113729]
#  [ 1.3501879 ]
#  [ 0.72916547]
#  [-0.08165156]
# ...

# %%
print(y2)
# Out:
# [-3.43198806e+01 -9.42120961e+00 -1.90881877e+01  2.04372122e+01
#   2.77559659e+01 -2.90750046e+00 -1.41987828e+01  5.40025891e+00
#  -2.64264302e+01 -3.49067872e+01  3.73362043e+01  1.28532816e+01
#   2.50289888e+01 -1.89608736e+01 -2.34655852e+01  3.77839324e+01
#   6.69670792e+00 -5.57201352e+00 -4.92158778e+01  1.59474399e+01
#  -4.29667324e+01  6.09015466e+00 -2.53194769e+01  6.28216706e+01
#   1.24870400e+01 -3.27136530e+01 -1.88255476e+01 -2.93912926e+01
#  -2.86886731e+01  4.38924069e+00  4.63542396e+01  2.43919519e+01
#   3.79848517e+01 -3.45767718e+01 -6.18736296e+01 -4.64421597e+01
#  -6.88808416e+00  3.96988084e+01 -3.52373298e+01  8.36850884e+00
#  -3.96814412e+01  8.27318308e+00 -4.40722161e+00 -3.01350607e+00
#   5.78213629e+01  2.46525603e+01  1.81131707e+01 -5.22849035e+01
#   3.59187182e+01  1.58411788e+01  2.40080546e+01 -2.51245994e+01
#  -4.39284313e+01  1.73925049e+01  1.50322799e+01  3.78339073e+01
# ...

# %%
plt.scatter(X2,y2)

# %%
from sklearn.linear_model import LinearRegression

Lr = LinearRegression()

Lr.fit(X2,y2)
print(Lr.coef_)
print(Lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
from sklearn.linear_model import Ridge


rr = Ridge(alpha=10)
rr.fit(X2,y2)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235726

# %%
rr1 = Ridge(alpha=100)
rr1.fit(X2,y2)
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033308

# %%
plt.plot(X2,y2,'b.')
plt.plot(X2,Lr.predict(X2),color='red',label='alpha=0')
plt.plot(X2,rr.predict(X2),color='green',label='alpha=10')
plt.plot(X2,rr1.predict(X2),color='orange',label='alpha=100')
plt.legend()

# %%
def linear_regression(X2,y2,aplha = 1):
    x_mean = X2.mean()
    y_mean = y2.mean()
    
    num = 0
    den = 0
    
    for i in range(X2.shape[0]):
        num = num + (y2[i] - y_mean) * (X2[i] - x_mean)
        den = den +  (X2[i] - x_mean) * (X2[i] - x_mean)
        
    m = num/den(den + alpha)
    b = y_mean - m*x_mean
    
    return m,b

# %%
class MeraRidge:
    
    def __init__(self,alpha=0.1):
        self.alpha = alpha
        self.m = None
        self.b = None
        
    def fit(self,X_train,y_train):
        
        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
            num = num + (y_train[i] - y_train.mean())*(X_train[i] - X_train.mean())
            den = den + (X_train[i] - X_train.mean())*(X_train[i] - X_train.mean())
        
        self.m = num/(den + self.alpha)
        self.b = y_train.mean() - (self.m*X_train.mean())
        print(self.m,self.b)
    
    def predict(X_test):
        pass

# %%
reg = MeraRidge(alpha=100)
reg

# %%
reg.fit(X,y)
# Out:
# [12.93442104] [-1.42484415]

# %% [markdown]
# # for nD input columns

# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np

# %%
X3,y3 = load_diabetes(return_X_y = True)

# %%
print(X3)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]

# %%
print(y3)
# Out:
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
#   65. 141.  55. 134.  42. 111.  98. 164.  48.  96.  90. 162. 150. 279.
#   92.  83. 128. 102. 302. 198.  95.  53. 134. 144. 232.  81. 104.  59.
#  246. 297. 258. 229. 275. 281. 179. 200. 200. 173. 180.  84. 121. 161.
#   99. 109. 115. 268. 274. 158. 107.  83. 103. 272.  85. 280. 336. 281.
#  118. 317. 235.  60. 174. 259. 178. 128.  96. 126. 288.  88. 292.  71.
#  197. 186.  25.  84.  96. 195.  53. 217. 172. 131. 214.  59.  70. 220.
#  268. 152.  47.  74. 295. 101. 151. 127. 237. 225.  81. 151. 107.  64.
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X3_train,X3_test,y3_train,y3_test = train_test_split(X3,y3,test_size=0.2,random_state=4)

# %%
print(X3_train)
# Out:
# [[ 0.0090156  -0.04464164  0.05522933 ...  0.02323852  0.05568623
#    0.10661708]
#  [ 0.03081083  0.05068012 -0.03422907 ...  0.05755657  0.0354587
#    0.08590655]
#  [ 0.01628068 -0.04464164 -0.06332999 ... -0.03949338 -0.05947118
#   -0.06735141]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [ 0.01628068  0.05068012  0.00996123 ... -0.03949338  0.01703607
#    0.00720652]
#  [ 0.04897352  0.05068012  0.08109682 ...  0.07120998  0.03243232
#    0.04862759]]

# %%
print(y3_train)
# Out:
# [173. 120.  65. 332. 107.  84.  48.  87.  53. 158.  71. 121. 244. 131.
#  152.  72. 118. 210. 140. 170.  49. 262.  61.  53.  52.  63. 181. 103.
#  277. 235.  97.  88. 197. 152. 187.  92. 150.  75. 131. 104. 160. 127.
#  243.  40.  61. 179.  53. 109.  49. 281. 257. 306. 115.  88. 252. 283.
#   79. 200. 275.  96. 259.  77. 103.  42.  60. 246. 110. 310. 111. 147.
#  190. 196.  91.  95. 265. 274. 116. 116.  83. 122. 270. 230. 275. 310.
#   67. 104. 280. 166.  94. 243. 164.  90.  85. 195. 177. 221. 102. 233.
#  249.  90.  72. 214. 144.  60. 270. 220.  68. 123.  45. 129. 182. 174.
#  127. 124. 257.  47.  88. 189.  71. 242. 178. 272.  68. 190. 219.  93.
#  233. 230. 297. 185. 138. 181. 321. 248. 264. 101. 281. 107. 308. 225.
#  102.  71.  53. 263. 168.  83. 281.  75. 150. 273.  55. 128. 163. 191.
#  261. 178. 275. 109. 124. 148. 144.  91.  52. 110.  78. 245.  59. 131.
#  200. 276. 179.  90. 245.  89.  98. 131. 102.  72.  43. 253.  81.  51.
# ...

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=0.1,solver='cholesky')

# %%
reg.fit(X3_train,y3_train)
# Out:
# Ridge(alpha=0.1, solver='cholesky')

# %%
y3_pred = reg.predict(X3_test)
r2_score(y3_test,y3_pred)
# Out:
# 0.46931288533098026

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  44.02063391 -241.69329987  452.98665299  332.04420177  -76.33686744
#   -68.52143809 -164.98809083  149.96908118  431.61347417   58.51862681]
# 150.89053425602808

# %%
class MeraRidge:
    
    def __init__(self,alpha=0.1):
        
        self.alpha = alpha
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self,X3_train,y3_train):
        
        X3_train = np.insert(X3_train,0,1,axis=1)
        I = np.identity(X3_train.shape[1])
        I[0][0] = 0
        result = np.linalg.inv(np.dot(X3_train.T,X3_train) + self.alpha * I).dot(X3_train.T).dot(y3_train)
        self.intercept_ = result[0]
        self.coef_ = result[1:]
    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
reg = MeraRidge()
reg.fit(X3_train,y3_train)
y3_pred = reg.predict(X3_test)
print(r2_score(y3_test,y3_pred))

print(reg.coef_)
print(reg.intercept_)
# Out:
# 0.4693128853309806
# [  44.02063391 -241.69329987  452.98665299  332.04420177  -76.33686744
#   -68.52143809 -164.98809083  149.96908118  431.61347417   58.51862681]
# 150.89053425602813

# %% [markdown]
# # Regularisation from Gradient Descent

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=0.001, max_iter=500,solver='sparse_cg')

# %%
reg.fit(X3_train,y3_train)

y3_pred = reg.predict(X3_test)
print("R2 score",r2_score(y3_test,y3_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score 0.4625010162027918
# [  34.52192778 -290.84083871  482.40181675  368.06786931 -852.44872818
#   501.59160694  180.11115474  270.76334443  759.73534802   37.49135796]
# 151.101985182554
