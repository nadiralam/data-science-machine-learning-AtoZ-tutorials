# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Lasso
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
print(X)
# Out:
# [[-0.71239066]
#  [-0.43714566]
#  [-0.45375238]
#  [ 0.95283061]
#  [ 0.23785784]
#  [ 0.86121137]
#  [-0.24332625]
#  [ 0.18494595]
#  [-0.72099967]
#  [-0.42989708]
#  [ 2.01522083]
#  [ 0.39724133]
#  [ 0.20780005]
#  [-0.23242587]
#  [-0.76862702]
#  [ 0.45315861]
#  [ 0.63988397]
#  [ 0.3595323 ]
#  [-1.61510796]
#  [ 1.74924179]
#  [-0.78898902]
#  [-0.51196509]
#  [-0.92833523]
#  [ 2.15038297]
#  [-0.2073497 ]
#  [-1.63909341]
#  [-0.33861825]
#  [-0.32212366]
#  [-0.48137142]
#  [-0.52316421]
#  [ 0.72196506]
#  [ 0.76591105]
#  [ 0.45348104]
#  [-1.26160595]
#  [-2.18711527]
#  [-1.18541881]
#  [ 0.21745166]
#  [ 1.33031692]
#  [-1.08718159]
#  [ 0.56226171]
#  [-1.51284512]
#  [-0.00238903]
#  [-0.27813452]
#  [ 0.45181234]
#  [ 1.19070527]
#  [ 0.92234415]
#  [ 0.81499544]
#  [-0.6209797 ]
#  [ 0.9137407 ]
#  [ 1.13833305]
#  [ 1.47868574]
#  [-0.65105648]
#  [-0.37591996]
#  [-0.77466003]
#  [ 0.50113729]
#  [ 1.3501879 ]
#  [ 0.72916547]
#  [-0.08165156]
#  [-0.85414295]
#  [ 0.46565797]
#  [-0.04450308]
#  [-0.05753239]
#  [ 1.89274222]
#  [-1.04537713]
#  [ 0.56465429]
#  [-1.92415945]
#  [-0.76403397]
#  [ 0.12730328]
#  [-0.02677165]
#  [-0.14521133]
#  [ 0.56284679]
#  [ 0.31735092]
#  [ 0.71097479]
#  [ 0.75376638]
#  [-0.37011608]
#  [ 1.34510171]
#  [ 0.53233789]
#  [-0.98416078]
#  [ 1.350306  ]
#  [-0.34660679]
#  [ 0.51432886]
#  [ 0.10126979]
#  [-0.65751727]
#  [ 0.83090566]
#  [-0.31726597]
#  [-0.98027432]
#  [ 1.39923842]
#  [ 0.54791831]
#  [-0.53032741]
#  [ 0.49087183]
#  [ 0.34875059]
#  [ 2.05369324]
#  [ 0.60628866]
#  [-0.38445769]
#  [-1.94539068]
#  [-0.31485808]
#  [ 1.84961257]
#  [-1.12050687]
#  [-0.33267578]
#  [-0.75745323]]

# %%
print(y)
# Out:
# [-3.43198806e+01 -9.42120961e+00 -1.90881877e+01  2.04372122e+01
#   2.77559659e+01 -2.90750046e+00 -1.41987828e+01  5.40025891e+00
#  -2.64264302e+01 -3.49067872e+01  3.73362043e+01  1.28532816e+01
#   2.50289888e+01 -1.89608736e+01 -2.34655852e+01  3.77839324e+01
#   6.69670792e+00 -5.57201352e+00 -4.92158778e+01  1.59474399e+01
#  -4.29667324e+01  6.09015466e+00 -2.53194769e+01  6.28216706e+01
#   1.24870400e+01 -3.27136530e+01 -1.88255476e+01 -2.93912926e+01
#  -2.86886731e+01  4.38924069e+00  4.63542396e+01  2.43919519e+01
#   3.79848517e+01 -3.45767718e+01 -6.18736296e+01 -4.64421597e+01
#  -6.88808416e+00  3.96988084e+01 -3.52373298e+01  8.36850884e+00
#  -3.96814412e+01  8.27318308e+00 -4.40722161e+00 -3.01350607e+00
#   5.78213629e+01  2.46525603e+01  1.81131707e+01 -5.22849035e+01
#   3.59187182e+01  1.58411788e+01  2.40080546e+01 -2.51245994e+01
#  -4.39284313e+01  1.73925049e+01  1.50322799e+01  3.78339073e+01
#   6.33015059e+00  5.07266140e+00 -5.57047189e+00  1.98411137e+01
#   7.04149700e+00 -1.89353310e+01  3.48047372e+01 -5.71391242e+01
#   3.10524837e+01 -7.57291461e+01 -4.43062883e+01  2.12404103e+01
#  -1.86288622e-01 -2.85657165e+01 -7.39169323e+00  2.52239775e+01
#   3.25432136e+01  2.93379129e-01 -1.86381423e+01  3.93501682e+01
#   2.54005098e+00 -4.86320699e+01  5.42818051e+01 -1.02170910e+01
#  -5.66921620e+00  2.34628620e+01 -6.92299670e-02  5.63079459e+00
#  -9.68771368e+00 -4.46638656e+01  3.27083097e+01  1.81174790e+01
#  -1.61432262e+01  4.50414413e+01  2.27466324e+01  3.71085471e+01
#   1.24760264e+01 -3.58452002e+01 -2.86386661e+01 -2.79790662e+01
#   6.41794705e+01 -6.07154394e+01  2.22333646e+01 -2.40222151e+00]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
print(X_train)
# Out:
# [[-0.65751727]
#  [-0.72099967]
#  [-0.76403397]
#  [-0.37011608]
#  [-0.2073497 ]
#  [-0.76862702]
#  [-0.32212366]
#  [-0.23242587]
#  [ 0.72916547]
#  [ 1.19070527]
#  [-1.94539068]
#  [-0.34660679]
#  [-0.31726597]
#  [-0.85414295]
#  [-0.52316421]
#  [-0.05753239]
#  [-0.42989708]
#  [ 0.53233789]
#  [ 0.83090566]
#  [-1.61510796]
#  [ 0.86121137]
#  [-1.08718159]
#  [-1.12050687]
#  [-0.53032741]
#  [ 1.13833305]
#  [ 0.81499544]
#  [ 0.20780005]
#  [ 0.54791831]
#  [-0.65105648]
#  [ 0.46565797]
#  [ 0.92234415]
#  [-1.92415945]
#  [-0.98027432]
#  [ 1.89274222]
#  [ 0.12730328]
#  [ 0.71097479]
#  [ 1.39923842]
#  [-0.02677165]
#  [-0.92833523]
#  [-0.48137142]
#  [-0.33861825]
#  [-0.27813452]
#  [ 2.15038297]
#  [-0.78898902]
#  [-0.00238903]
#  [-1.63909341]
#  [ 0.49087183]
#  [-0.04450308]
#  [-0.37591996]
#  [ 0.75376638]
#  [-0.77466003]
#  [-1.51284512]
#  [ 0.39724133]
#  [ 1.74924179]
#  [ 1.47868574]
#  [ 0.9137407 ]
#  [-0.24332625]
#  [-1.18541881]
#  [-0.33267578]
#  [-0.51196509]
#  [ 0.3595323 ]
#  [-0.6209797 ]
#  [ 0.31735092]
#  [-0.38445769]
#  [ 1.3501879 ]
#  [-2.18711527]
#  [-0.43714566]
#  [ 1.84961257]
#  [ 0.45348104]
#  [ 2.05369324]
#  [-0.71239066]
#  [ 0.45181234]
#  [-0.14521133]
#  [ 0.76591105]
#  [ 0.50113729]
#  [-1.04537713]
#  [-0.98416078]
#  [ 0.56226171]
#  [ 0.10126979]
#  [-0.31485808]]

# %%
print(y_train)
# Out:
# [-6.92299670e-02 -2.64264302e+01 -4.43062883e+01 -1.86381423e+01
#   1.24870400e+01 -2.34655852e+01 -2.93912926e+01 -1.89608736e+01
#   6.33015059e+00  5.78213629e+01 -2.86386661e+01 -1.02170910e+01
#  -9.68771368e+00 -5.57047189e+00  4.38924069e+00 -1.89353310e+01
#  -3.49067872e+01  2.54005098e+00  5.63079459e+00 -4.92158778e+01
#  -2.90750046e+00 -3.52373298e+01 -6.07154394e+01 -1.61432262e+01
#   1.58411788e+01  1.81131707e+01  2.50289888e+01  1.81174790e+01
#  -2.51245994e+01  1.98411137e+01  2.46525603e+01 -7.57291461e+01
#  -4.46638656e+01  3.48047372e+01  2.12404103e+01  3.25432136e+01
#   3.27083097e+01 -1.86288622e-01 -2.53194769e+01 -2.86886731e+01
#  -1.88255476e+01 -4.40722161e+00  6.28216706e+01 -4.29667324e+01
#   8.27318308e+00 -3.27136530e+01  4.50414413e+01  7.04149700e+00
#  -4.39284313e+01  2.93379129e-01  1.73925049e+01 -3.96814412e+01
#   1.28532816e+01  1.59474399e+01  2.40080546e+01  3.59187182e+01
#  -1.41987828e+01 -4.64421597e+01  2.22333646e+01  6.09015466e+00
#  -5.57201352e+00 -5.22849035e+01  2.52239775e+01 -3.58452002e+01
#   3.78339073e+01 -6.18736296e+01 -9.42120961e+00  6.41794705e+01
#   3.79848517e+01  3.71085471e+01 -3.43198806e+01 -3.01350607e+00
#  -2.85657165e+01  2.43919519e+01  1.50322799e+01 -5.71391242e+01
#  -4.86320699e+01  8.36850884e+00  2.34628620e+01 -2.79790662e+01]

# %%
plt.scatter(X,y)

from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train,y_train)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [27.66816614]
# -3.4544553128738826

# %%
alpha = [0,1,5,10,30]
plt.figure(figsize = (10,6))
plt.scatter(X,y)

for i in alpha:
    L = Lasso(alpha = i)
    L.fit(X_train,y_train)
    plt.plot(X_test,L.predict(X_test),label = 'alpha = {}'.format(i))
    
plt.legend()
plt.show()
# Out:
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\base.py:1474: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e+04, tolerance: 7.819e+00 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
m = 100
x1 = 5 * np.random.rand(m, 1) - 2
x2 = 0.7 * x1 ** 2 - 2 * x1 + 3 + np.random.randn(m, 1)

plt.scatter(x1, x2)
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

def get_preds_lasso(x1, x2, alpha):
    model = Pipeline([
        ('poly_feats', PolynomialFeatures(degree=16)),
        ('lasso', Lasso(alpha=alpha))
    ])
    model.fit(x1, x2)
    return model.predict(x1)

alphas = [0, 0.1, 1]
cs = ['r', 'g', 'b']

plt.figure(figsize=(10, 6))
plt.plot(x1, x2, 'b+', label='Datapoints')

for alpha, c in zip(alphas, cs):
    preds = get_preds_lasso(x1, x2, alpha)
    # Plot
    plt.plot(sorted(x1[:, 0]), preds[np.argsort(x1[:, 0])], c, label='Alpha: {}'.format(alpha))

plt.legend()
plt.show()
# Out:
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\base.py:1474: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.099e+01, tolerance: 7.897e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.571e+01, tolerance: 7.897e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\NADIR\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.622e+02, tolerance: 7.897e-02
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # ElasticNet

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# Linear Regression

reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
# Ridge 

reg = Ridge(alpha=0.1)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.45199494197195456

# %%
# Lasso

reg = Lasso(alpha=0.01)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.441118559631106

# %%
# ElasticNet

reg = ElasticNet(alpha=0.005,l1_ratio=0.9)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4531474541554822
