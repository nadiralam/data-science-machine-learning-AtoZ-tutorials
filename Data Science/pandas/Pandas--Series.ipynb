# %%
import numpy as np
import pandas as pd

# %%
# list
# string

country = ['India','USA','Nepal','Pakistan','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1         USA
# 2       Nepal
# 3    Pakistan
# 4    Srilanka
# dtype: object

# %%
# integer

runs = [45,67,89,88,99,100]
pd.Series(runs)
# Out:
# 0     45
# 1     67
# 2     89
# 3     88
# 4     99
# 5    100
# dtype: int64

# %%
# custom index

subjects = ['Science','Social','Math','Hindi','English']
marks = [89,77,88,100,90]
marks_series = pd.Series(marks,index = subjects,name = "Nadir ke marks")
marks_series
# Out:
# Science     89
# Social      77
# Math        88
# Hindi      100
# English     90
# Name: Nadir ke marks, dtype: int64

# %%
# Dictionary

Dict = {
    'Science':89,
    'Social':77,
    'Math':88,
    'Hindi':100,
    'English':90
}
pd.Series(Dict,name = "Nadir ke marks")
# Out:
# Science     89
# Social      77
# Math        88
# Hindi      100
# English     90
# Name: Nadir ke marks, dtype: int64

# %%
# size

marks_series.size
# Out:
# 5

# %%
# is_unique

marks_series.is_unique
# Out:
# True

# %%
marks_series.dtypes
# Out:
# dtype('int64')

# %%
marks_series.index
# Out:
# Index(['Science', 'Social', 'Math', 'Hindi', 'English'], dtype='object')

# %%
marks_series.values
# Out:
# array([ 89,  77,  88, 100,  90], dtype=int64)

# %%
subs = pd.read_csv("subs.csv",squeeze = True)
subs
# Out:
# C:\Users\NADIR\AppData\Local\Temp\ipykernel_1100\1806544333.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   subs = pd.read_csv("subs.csv",squeeze = True)
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv("kohli_ipl.csv",index_col = 'match_no',squeeze = True)
vk
# Out:
# C:\Users\NADIR\AppData\Local\Temp\ipykernel_1100\1217499299.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   vk = pd.read_csv("kohli_ipl.csv",index_col = 'match_no',squeeze = True)
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv("bollywood.csv",index_col = 'movie',squeeze = True)
movies
# Out:
# C:\Users\NADIR\AppData\Local\Temp\ipykernel_1100\3329534779.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   movies = pd.read_csv("bollywood.csv",index_col = 'movie',squeeze = True)
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies["movie"]
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1495                  Hum Tumhare Hain Sanam
# 1496                     Aankhen (2002 film)
# 1497                         Saathiya (film)
# 1498                          Company (film)
# 1499                    Awara Paagal Deewana
# Name: movie, Length: 1500, dtype: object

# %%
movies["lead"]
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1495      Shah Rukh Khan
# 1496    Amitabh Bachchan
# 1497        Vivek Oberoi
# 1498          Ajay Devgn
# 1499        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.head(5)
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
subs.tail(10)
# Out:
# 355    149
# 356    156
# 357    177
# 358    210
# 359    209
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
movies.sample()
# Out:
# movie
# Dil Jo Bhi Kahey...    Amitabh Bachchan
# Name: lead, dtype: object

# %%
movies.sample(7)
# Out:
# movie
# Pranaam                        Rajeev Khandelwal
# The Stoneman Murders               Kay Kay Menon
# Gangs of Wasseypur – Part 2       Manoj Bajpayee
# Lipstick Under My Burkha            Aahana Kumra
# Hum Tumhare Hain Sanam            Shah Rukh Khan
# Chillar Party                       Aarav Khanna
# Darwaaza Bandh Rakho                  Ishrat Ali
# Name: lead, dtype: object

# %%
movies.value_counts()
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: lead, Length: 566, dtype: int64

# %%
movies.value_counts(ascending = True)
# Out:
# Sharib Hashmi        1
# Ravi Kishan          1
# Sagar Bhangade       1
# Harish Chabbra       1
# Bidita Bag           1
#                     ..
# Sanjay Dutt         26
# Salman Khan         31
# Ajay Devgn          38
# Amitabh Bachchan    45
# Akshay Kumar        48
# Name: lead, Length: 566, dtype: int64

# %%
vk.sort_values()
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending = False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending = False).head(1).values[0]
# Out:
# 113

# %%
movies.sort_index
# Out:
# <bound method Series.sort_index of movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object>

# %%
subs.sum()
# Out:
# 49510

# %%
subs.prod()
# Out:
# 0

# %%
vk.mean()
# Out:
# 30.855813953488372

# %%
vk.median()
# Out:
# 24.0

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
vk.std()
# Out:
# 26.22980132830278

# %%
subs.var()
# Out:
# 3928.1585127201556

# %%
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
x = pd.Series([12,435,67,89,55,78])
x
# Out:
# 0     12
# 1    435
# 2     67
# 3     89
# 4     55
# 5     78
# dtype: int64

# %%
x[0]
# Out:
# 12

# %%
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 x[-1]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
# ...

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies['Hum Tumhare Hain Sanam']
# Out:
# 'Shah Rukh Khan'

# %%
movies[0]
# Out:
# 'Vicky Kaushal'

# %%
movies[-1]
# Out:
# 'Akshay Kumar'

# %%
# Slicing

vk[5:20]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# 17    22
# 18    19
# 19    16
# 20    15
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# Fancy Indexing

vk[[1,6,40,100]]
# Out:
# match_no
# 1       1
# 6       9
# 40     12
# 100    13
# Name: runs, dtype: int64

# %%
# Fancy Indexing with labels
movies['The Accidental Prime Minister (film)']
# Out:
# 'Anupam Kher'

# %%
# Editing Series

runs[1] = 98
runs
# Out:
# [45, 98, 89, 88, 99, 100]

# %%
marks_series
# Out:
# Science     89
# Social      77
# Math        88
# Hindi      100
# English     90
# Name: Nadir ke marks, dtype: int64

# %%
marks_series['Social'] = 87
marks_series
# Out:
# Science     89
# Social      87
# Math        88
# Hindi      100
# English     90
# Name: Nadir ke marks, dtype: int64

# %%
marks_series[3] = 80
marks_series
# Out:
# Science    89
# Social     87
# Math       88
# Hindi      80
# English    90
# Name: Nadir ke marks, dtype: int64

# %%
# Editing through slicing
runs[1:3] = 0,0
runs
# Out:
# [45, 0, 0, 88, 99, 100]

# %%
# Editing through fancy indexing

movies['Hum Tumhare Hain Sanam '] = 'Salman Khan'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Hum Tumhare Hain Sanam                       Salman Khan
# Name: lead, Length: 1501, dtype: object

# %%
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
list(marks_series)
# Out:
# [89, 77, 88, 100, 90]

# %%
type(list(marks_series))
# Out:
# list

# %%
# Membership operator
'Evening Shadows' in movies
# Out:
# True

# %%
'Pathaan'in movies
# Out:
# False

# %%
# looping

for i in movies:
    print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in vk:
    print(i)
# Out:
# 1
# 23
# 13
# 12
# 1
# 9
# 34
# 0
# 21
# 3
# 10
# 38
# 3
# 11
# 50
# 2
# 22
# 19
# 16
# 15
# 20
# 38
# 19
# 24
# 7
# 2
# 16
# 17
# 24
# 38
# 34
# 42
# 13
# 58
# 3
# 14
# 37
# 9
# 23
# 12
# 71
# 35
# 30
# 56
# 67
# 27
# 27
# 39
# 15
# 11
# 31
# 70
# 8
# 35
# 8
# 6
# 57
# 22
# 16
# 4
# 16
# 18
# 45
# 9
# 36
# 9
# 3
# 73
# 42
# 24
# 51
# 35
# 58
# 65
# 1
# 11
# 1
# 32
# 25
# 57
# 93
# 99
# 17
# 14
# 56
# 49
# 0
# 31
# 21
# 4
# 0
# 35
# 0
# 4
# 10
# 27
# 67
# 38
# 73
# 13
# 41
# 18
# 51
# 62
# 35
# 1
# 34
# 48
# 32
# 82
# 19
# 44
# 1
# 12
# 12
# 75
# 79
# 33
# 80
# 100
# 14
# 52
# 108
# 20
# 7
# 109
# 75
# 113
# 54
# 0
# 54
# 62
# 28
# 64
# 0
# 10
# 55
# 20
# 6
# 5
# 58
# 31
# 21
# 57
# 92
# 30
# 18
# 68
# 32
# 8
# 39
# 70
# 48
# 12
# 4
# 6
# 46
# 3
# 23
# 84
# 41
# 67
# 8
# 100
# 9
# 13
# 23
# 25
# 16
# 18
# 9
# 7
# 29
# 1
# 72
# 43
# 43
# 90
# 48
# 14
# 33
# 50
# 8
# 6
# 33
# 33
# 5
# 72
# 8
# 12
# 35
# 5
# 25
# 5
# 4
# 25
# 51
# 53
# 39
# 41
# 12
# 5
# 48
# 1
# 12
# 0
# 0
# 9
# 58
# ...

# %%
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic operator

100+ marks_series
# Out:
# Science    189
# Social     177
# Math       188
# Hindi      200
# English    190
# Name: Nadir ke marks, dtype: int64

# %%
100- marks_series
# Out:
# Science    11
# Social     23
# Math       12
# Hindi       0
# English    10
# Name: Nadir ke marks, dtype: int64

# %%
# relational operator
vk[vk>50].count()
# Out:
# 48

# %%
# find the no. of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# find no. of ducks
vk[vk  == 0].size
# Out:
# 9

# %%
# count no. of days when I had more than 200 subs a day

subs[subs>=200].count()
# Out:
# 59

# %%
# find actor who have done more than 20 movies

temp = movies.value_counts()
temp[temp>=20].count()
# Out:
# 7

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(25).plot(kind = "bar")
# Out:
# <Axes: >

# %%
vk[vk>=50].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
movies.value_counts().head(15).plot(kind = "pie")
# Out:
# <Axes: ylabel='lead'>
